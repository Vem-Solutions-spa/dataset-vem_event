# %%
import pandas as pd #USARE IMPORTAZIONE DF2
import pymysql

# %%
connection = pymysql.connect('194.116.76.192', 'bd7', 'bd7', 'final_project')

# %%
df=pd.read_sql("""SELECT car_id, start_time, end_time, ST_X(start_pos) AS start_lon, ST_Y(start_pos) AS start_lat, ST_X(end_pos) AS end_lon, ST_Y(end_pos) AS end_lat
FROM trips3 WHERE  start_time between  "2017-06-24 18:00:00" and  "2017-06-24 23:59:00"  """, connection, parse_dates = ["start_time","end_time"])

# %%
df.head()
# Out:
#     car_id          start_time            end_time  start_lon  start_lat  \
# 0  3100847 2017-06-24 23:08:00 2017-06-24 23:29:00   7.489069  44.649178
# 1  3101010 2017-06-24 18:05:00 2017-06-24 18:13:00   8.876479  44.890762
# 2  3101010 2017-06-24 18:13:00 2017-06-24 18:27:00   8.871661  44.907906
# 3  3101010 2017-06-24 18:27:00 2017-06-24 18:53:00   8.871634  44.907936
# 4  3101010 2017-06-24 18:53:00 2017-06-25 08:02:00   8.867557  44.901508
#
#     end_lon    end_lat
# 0  7.390215  44.653786
# 1  8.871661  44.907906
# 2  8.871634  44.907936
# 3  8.867557  44.901508
# 4  8.867541  44.901558

# %%
a=df.start_time

# %%
type(a[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
def csvExtraction(filename):
    df2=df.loc[(df.start_lon>=7.5991039) & (df.start_lon<=7.7687073) & (df.start_lat>=44.9941845) & (df.start_lat<=45.1253822) ]
    df2.groupby('car_id')
    df2=df2[['start_lat','start_lon']]
    df2.to_csv('out.csv',header=None,index=False)
    print (df2.shape)
    return df2

# %%
df2=csvExtraction(df)
# Out:
# (8070, 2)

# %%
df2.head()
# Out:
#    start_lat  start_lon
# 5  45.001434   7.666854
# 6  45.001091   7.666297
# 7  45.000988   7.666361
# 8  45.003162   7.666608
# 9  45.003139   7.666687

# %%
import matplotlib.pyplot as plt
import numpy as np
df2.plot(x='start_lat', y='start_lon', kind='scatter')
plt.title('Positions')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as pl
import scipy.stats as st

#data = np.random.multivariate_normal((0, 0), [[0.8, 0.05], [0.05, 0.7]], 100)
x = df2.start_lon
y = df2.start_lat
xmin, xmax = 7.5991039, 7.7687073
ymin, ymax = 44.9941845 , 45.1253822

# Peform the kernel density estimate
xx, yy = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([xx.ravel(), yy.ravel()])
values = np.vstack([x, y])
kernel = st.gaussian_kde(values)
f = np.reshape(kernel(positions).T, xx.shape)

fig = pl.figure()
ax = fig.gca()
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
# Contourf plot
cfset = ax.contourf(xx, yy, f, cmap='Blues')
## Or kernel density estimate plot instead of the contourf plot
#ax.imshow(np.rot90(f), cmap='Blues', extent=[xmin, xmax, ymin, ymax])
# Contour plot
cset = ax.contour(xx, yy, f, colors='k')
# Label plot
ax.clabel(cset, inline=1, fontsize=10)
ax.set_xlabel('Y1')
ax.set_ylabel('Y0')

pl.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl

Y = (df2.start_lon, df2.start_lat)
ax = sns.kdeplot(df2.start_lon,df2.start_lat, shade = True, cmap = "PuBu")
ax.patch.set_facecolor('white')
ax.collections[0].set_alpha(0)
ax.set_xlabel('$Y_1$', fontsize = 15)
ax.set_ylabel('$Y_0$', fontsize = 15)
pl.xlim(7.5991039, 7.7687073)
pl.ylim(44.9941845, 45.1253822)
#pl.plot([7.6, 7.77], [45.0, 45.12], color = "black", linewidth = 1)
pl.show()

# %%
kernel.shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-144-ea87c1ff6a98> in <module>()
# ----> 1 kernel.shape()
#
# AttributeError: 'gaussian_kde' object has no attribute 'shape'

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(df2.start_lon, df2.start_lat, s=50);

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=100)

kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.scatter(df2.start_lon, df2.start_lat, c=y_kmeans,  cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black',  alpha=0.5);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: (42, None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4273                 # must be acceptable as PathCollection facecolors
# -> 4274                 colors = mcolors.to_rgba_array(c)
#    4275             except ValueError:
#
# ...
